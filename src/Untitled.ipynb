# %%
import pandas as pd

# %%
df = pd.read_pickle('../data/quakes_last_24.pkl')

# %%
df
# Out:
#      mag                                  place              time  \
# 0   2.50     27 km ENE of Susitna North, Alaska  2023-11-18 00:04
# 1   4.90         48 km SSW of Banjar, Indonesia  2023-11-17 23:34
# 2   2.50               23 km E of Forsan, Texas  2023-11-17 23:32
# 3   4.60             66 km SSW of Sola, Vanuatu  2023-11-17 21:05
# 4   4.20          197 km ESE of Chiniak, Alaska  2023-11-17 19:13
# 5   4.90          south of the Kermadec Islands  2023-11-17 17:40
# 6   2.95            6 km NNW of Delta, B.C., MX  2023-11-17 15:10
# 7   2.86            8 km NNW of Delta, B.C., MX  2023-11-17 15:10
# 8   3.17             14 km S of Volcano, Hawaii  2023-11-17 14:57
# 9   3.80                29 km N of Adak, Alaska  2023-11-17 14:53
# 10  2.75              5 km N of Delta, B.C., MX  2023-11-17 14:11
# 11  3.10      14 km NNW of Meadow Lakes, Alaska  2023-11-17 13:35
# 12  4.10            22 km NW of Émponas, Greece  2023-11-17 13:19
# ...
