# %%
import os
import requests
from datetime import datetime

import pandas as pd
from pandas.io.json import json_normalize

import folium
from folium import plugins

# %%
df = pd.read_csv('../data/tsunamis-2022-04-27_23-16-51_-0400.tsv', sep='\t')

# %%
df.tail()
# Out:
#      Search Parameters    Year   Mo    Dy    Hr    Mn   Sec  \
# 2652               NaN  2022.0  1.0  16.0   NaN   NaN   NaN
# 2653               NaN  2022.0  1.0  29.0   2.0  46.0  39.0
# 2654               NaN  2022.0  3.0  16.0  14.0  36.0  33.0
# 2655               NaN  2022.0  3.0  30.0  20.0  56.0  58.0
# 2656               NaN  2022.0  3.0  31.0   5.0  44.0   1.0
#
#       Tsunami Event Validity  Tsunami Cause Code  Earthquake Magnitude  ...  \
# 2652                     4.0                 6.0                   NaN  ...
# 2653                     4.0                 1.0                   6.5  ...
# 2654                     4.0                 1.0                   7.3  ...
# 2655                     4.0                 1.0                   6.9  ...
# 2656                     4.0                 1.0                   7.0  ...
#
#       Total Missing  Total Missing Description  Total Injuries  \
# 2652            NaN                        NaN             NaN
# 2653            NaN                        NaN             NaN
# 2654            NaN                        NaN           107.0
# 2655            NaN                        NaN             NaN
# 2656            NaN                        NaN             NaN
#
#      Total Injuries Description Total Damage ($Mil)  Total Damage Description  \
# 2652                        NaN                 NaN                       NaN
# 2653                        NaN                 NaN                       NaN
# 2654                        3.0                 NaN                       2.0
# 2655                        NaN                 NaN                       NaN
# 2656                        NaN                 NaN                       NaN
#
#       Total Houses Destroyed  Total Houses Destroyed Description  \
# 2652                     NaN                                 NaN
# 2653                     NaN                                 NaN
# 2654                     NaN                                 NaN
# 2655                     NaN                                 NaN
# 2656                     NaN                                 NaN
#
#       Total Houses Damaged  Total Houses Damaged Description
# 2652                   NaN                               NaN
# 2653                   NaN                               NaN
# 2654                   NaN                               NaN
# 2655                   NaN                               NaN
# 2656                   NaN                               NaN
#
# [5 rows x 46 columns]

# %%
df.shape
# Out:
# (2657, 46)

# %%
for col in df.columns:
    unique_values = df[col].nunique()
    print(f"{col}: {unique_values}")
# Out:
# Search Parameters: 1
# Year: 456
# Mo: 12
# Dy: 31
# Hr: 24
# Mn: 60
# Sec: 361
# Tsunami Event Validity: 6
# Tsunami Cause Code: 12
# Earthquake Magnitude: 52
# Vol: 162
# More Info: 0
# Deposits: 19
# Country: 111
# Location Name: 968
# Latitude: 1407
# Longitude: 1631
# Maximum Water Height (m): 240
# Number of Runups: 113
# Tsunami Magnitude (Abe): 1
# Tsunami Magnitude (Iida): 64
# Tsunami Intensity: 32
# Deaths: 119
# Death Description: 4
# Missing: 4
# Missing Description: 3
# Injuries: 47
# Injuries Description: 4
# Damage ($Mil): 41
# Damage Description: 4
# Houses Destroyed: 67
# Houses Destroyed Description: 4
# Houses Damaged: 14
# Houses Damaged Description: 4
# Total Deaths: 231
# Total Death Description: 4
# Total Missing: 10
# Total Missing Description: 4
# Total Injuries: 161
# Total Injuries Description: 4
# Total Damage ($Mil): 109
# Total Damage Description: 4
# Total Houses Destroyed: 163
# Total Houses Destroyed Description: 4
# Total Houses Damaged: 76
# Total Houses Damaged Description: 4

# %% [markdown]
# ### That's a lot of columns; certainly more than I need. Also, the ones before there was good earthquake data are nice to know historically but basically useless for my purposes. Long term records start at about 1990, so I'll use that as a cutoff for now. Also, I'm only using `Event Validity` of 4 for now. Beyond that, I can drop a lot of the damage, death and missing people columns.

# %%
df.shape
# Out:
# (339, 19)

# %%
df = df[df['Year'] >= 1990]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/quake/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/quake/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/quake/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df = df[df['Year'] >= 1990]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/quake/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/quake/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Year'

# %%
df = df[df['Tsunami Event Validity'] == 4]

# %%
df.head(3)

# %%
cols = df.columns.to_list()
cols

drop_cols = [ 'Deaths',
 'Death Description',
 'Missing',
 'Missing Description',
 'Injuries',
 'Injuries Description',
 'Damage ($Mil)',
 'Damage Description',
 'Houses Destroyed',
 'Houses Destroyed Description',
 'Houses Damaged',
 'Houses Damaged Description',
 'Total Deaths',
 'Total Death Description',
 'Total Missing',
 'Total Missing Description',
 'Total Injuries',
 'Total Injuries Description',
 'Total Damage ($Mil)',
 'Total Damage Description',
 'Total Houses Destroyed',
 'Total Houses Destroyed Description',
 'Total Houses Damaged',
 'Total Houses Damaged Description',
 'More Info',
 'Search Parameters',
 'Vol',
 'Deposits'
]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/quake/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/quake/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/quake/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df = df[df['Year'] >= 1990]
#       2 df.head(3)
#       4 df = df[df['Tsunami Event Validity'] == 4]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/quake/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/quake/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Year'

# %%
df = df.drop(columns = drop_cols)

# %%
df.columns
# Out:
# Index(['Year', 'Mo', 'Dy', 'Hr', 'Mn', 'Sec', 'Tsunami Event Validity',
#        'Tsunami Cause Code', 'Earthquake Magnitude', 'Country',
#        'Location Name', 'Latitude', 'Longitude', 'Maximum Water Height (m)',
#        'Number of Runups', 'Tsunami Magnitude (Abe)',
#        'Tsunami Magnitude (Iida)', 'Tsunami Intensity'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Year                        float64
# Mo                          float64
# Dy                          float64
# Hr                          float64
# Mn                          float64
# Sec                         float64
# Tsunami Event Validity      float64
# Tsunami Cause Code          float64
# Earthquake Magnitude        float64
# Country                      object
# Location Name                object
# Latitude                    float64
# Longitude                   float64
# Maximum Water Height (m)    float64
# Number of Runups            float64
# Tsunami Magnitude (Abe)     float64
# Tsunami Magnitude (Iida)    float64
# Tsunami Intensity           float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 339 entries, 2232 to 2656
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      339 non-null    float64
#  1   Mo                        339 non-null    float64
#  2   Dy                        339 non-null    float64
#  3   Hr                        319 non-null    float64
#  4   Mn                        317 non-null    float64
#  5   Sec                       304 non-null    float64
#  6   Tsunami Event Validity    339 non-null    float64
#  7   Tsunami Cause Code        339 non-null    float64
#  8   Earthquake Magnitude      300 non-null    float64
#  9   Country                   339 non-null    object
#  10  Location Name             339 non-null    object
#  11  Latitude                  332 non-null    float64
#  12  Longitude                 332 non-null    float64
#  13  Maximum Water Height (m)  327 non-null    float64
#  14  Number of Runups          339 non-null    float64
#  15  Tsunami Magnitude (Abe)   1 non-null      float64
#  16  Tsunami Magnitude (Iida)  59 non-null     float64
#  17  Tsunami Intensity         55 non-null     float64
# dtypes: float64(16), object(2)
# memory usage: 50.3+ KB

# %%
df2 = df[df[['Year', 'Mo', 'Dy', 'Hr', 'Mn', 'Sec']].isna().any(axis=1)]
df2
# Out:
#         Year    Mo    Dy    Hr    Mn  Sec  Tsunami Event Validity  \
# 2249  1992.0   1.0   5.0   6.0   NaN  NaN                     4.0
# 2271  1994.0   4.0  28.0  11.0  30.0  NaN                     4.0
# 2279  1994.0   9.0  19.0   NaN   NaN  NaN                     4.0
# 2283  1994.0  11.0   4.0   4.0  12.0  NaN                     4.0
# 2306  1996.0   1.0   1.0   NaN   NaN  NaN                     4.0
# 2307  1996.0   1.0   2.0  15.0  40.0  NaN                     4.0
# 2330  1997.0  12.0  26.0   8.0   NaN  NaN                     4.0
# 2331  1998.0   3.0  19.0  18.0  30.0  NaN                     4.0
# 2337  1999.0   1.0  20.0   NaN   NaN  NaN                     4.0
# 2339  1999.0   9.0  13.0   NaN   NaN  NaN                     4.0
# 2365  2002.0  12.0  30.0  12.0  15.0  NaN                     4.0
# 2370  2003.0   7.0  12.0   NaN   NaN  NaN                     4.0
# 2396  2005.0  12.0   9.0   1.0  57.0  NaN                     4.0
# 2400  2006.0   5.0  20.0  11.0  20.0  NaN                     4.0
# 2401  2006.0   6.0  15.0   NaN   NaN  NaN                     4.0
# 2427  2007.0  12.0   4.0   NaN   NaN  NaN                     4.0
# 2435  2008.0   8.0   8.0   NaN   NaN  NaN                     4.0
# 2500  2012.0   7.0  15.0   NaN   NaN  NaN                     4.0
# 2513  2013.0   6.0  13.0   NaN   NaN  NaN                     4.0
# 2517  2013.0   9.0  24.0   NaN   NaN  NaN                     4.0
# 2531  2014.0   6.0  23.0   NaN   NaN  NaN                     4.0
# 2532  2014.0   6.0  27.0  10.0  37.0  NaN                     4.0
# 2544  2015.0   5.0  10.0   NaN   NaN  NaN                     4.0
# 2551  2015.0  10.0  18.0   5.0  19.0  NaN                     4.0
# 2573  2017.0   3.0  19.0   4.0  30.0  NaN                     4.0
# 2594  2018.0   2.0   9.0   NaN   NaN  NaN                     4.0
# 2597  2018.0   5.0  15.0   NaN   NaN  NaN                     4.0
# 2610  2018.0  12.0  22.0  13.0  55.0  NaN                     4.0
# 2612  2019.0   4.0  14.0  23.0  17.0  NaN                     4.0
# 2622  2020.0   4.0  23.0   NaN   NaN  NaN                     4.0
# 2625  2020.0   6.0  13.0   NaN   NaN  NaN                     4.0
# 2649  2022.0   1.0  13.0   NaN   NaN  NaN                     4.0
# 2650  2022.0   1.0  14.0   NaN   NaN  NaN                     4.0
# 2651  2022.0   1.0  15.0   4.0  27.0  NaN                     4.0
# 2652  2022.0   1.0  16.0   NaN   NaN  NaN                     4.0
#
#       Tsunami Cause Code  Earthquake Magnitude           Country  \
# 2249                 1.0                   3.7             CHINA
# 2271                 8.0                   NaN            NORWAY
# 2279                 6.0                   NaN  PAPUA NEW GUINEA
# 2283                 8.0                   NaN               USA
# 2306                 8.0                   NaN            GREECE
# 2307                 6.0                   NaN            RUSSIA
# 2330                 7.0                   NaN        MONTSERRAT
# 2331                 8.0                   NaN            NORWAY
# 2337                 6.0                   NaN        MONTSERRAT
# 2339                 8.0                   NaN  FRENCH POLYNESIA
# 2365                 7.0                   NaN             ITALY
# 2370                 6.0                   NaN        MONTSERRAT
# 2396                 9.0                   NaN            CANADA
# 2400                 6.0                   NaN        MONTSERRAT
# 2401                 9.0                   NaN             SPAIN
# 2427                 8.0                   NaN            CANADA
# 2435                 6.0                   NaN               USA
# 2500                 8.0                   NaN         GREENLAND
# 2513                 9.0                   NaN               USA
# 2517                 3.0                   NaN          PAKISTAN
# 2531                 9.0                   NaN             SPAIN
# 2532                 8.0                   NaN           UKRAINE
# 2544                 8.0                   NaN            NORWAY
# 2551                 8.0                   NaN               USA
# 2573                 9.0                   NaN              IRAN
# 2594                 6.0                   NaN  PAPUA NEW GUINEA
# 2597                 9.0                   NaN               USA
# 2610                 7.0                   NaN         INDONESIA
# 2612                 9.0                   NaN               USA
# 2622                 9.0                   NaN               USA
# 2625                 9.0                   NaN               USA
# 2649                 6.0                   NaN             TONGA
# 2650                 6.0                   NaN             TONGA
# 2651                 6.0                   NaN             TONGA
# 2652                 6.0                   NaN             TONGA
#
#                            Location Name  Latitude  Longitude  \
# 2249                     SOUTH CHINA SEA    18.000    108.000
# 2271                      WESTERN NORWAY    61.267      6.583
# 2279                    PAPUA NEW GUINEA    -4.238    152.214
# 2283                         SKAGWAY, AK    59.500   -135.300
# 2306                     W. CORINTH GULF    38.367     22.083
# 2307       KARYMSKOYE, KAMCHATKA, RUSSIA    54.050    159.430
# 2330                  WHITE RIVER VALLEY    16.720    -62.180
# 2331                      WESTERN NORWAY    61.183      5.267
# 2337             SOUFRIERE HILLS VOLCANO    16.722    -62.180
# 2339                           FATU HIVA   -10.520   -138.670
# 2365                    STROMBOLI ISLAND    38.789     15.213
# 2370             SOUFRIERE HILLS VOLCANO    16.722    -62.180
# 2396                    BRITISH COLUMBIA       NaN        NaN
# 2400             SOUFRIERE HILLS VOLCANO    16.722    -62.180
# 2401          CIUTADELLA, MENORCA ISLAND    40.000      3.830
# 2427           CHEHALIS LAKE, CHILLIWACK    49.475   -121.847
# 2435  KASATOCHI VOLCANO, ALEUTIAN IS, AK    52.180   -175.500
# 2500       ILULISSAT ICEFJORD, GREENLAND    69.200    -51.300
# 2513            NORTHWEST ATLANTIC OCEAN       NaN        NaN
# 2517                    OFF COAST GWADAR    25.180     62.260
# 2531        MEDITERRANEAN AND BLACK SEAS       NaN        NaN
# 2532                              ODESSA    46.320     30.670
# 2544                     NORTHERN NORWAY    69.800     20.920
# 2551                         ICY BAY, AK    60.080   -141.300
# 2573                        PERSIAN GULF    27.835     51.940
# 2594    KADOVAR ISLAND, PAPUA NEW GUINEA    -3.608    144.588
# 2597                    NORTHEAST U.S.A.       NaN        NaN
# 2610                            KRAKATAU    -6.102    105.423
# 2612                           LAKE ERIE       NaN        NaN
# 2622                      GULF OF MEXICO       NaN        NaN
# 2625                      GULF OF MEXICO       NaN        NaN
# 2649                       TONGA ISLANDS   -20.536   -175.382
# 2650                       TONGA ISLANDS   -20.536   -175.382
# 2651                       TONGA ISLANDS   -20.536   -175.382
# 2652                       TONGA ISLANDS   -20.536   -175.382
#
#       Maximum Water Height (m)  Number of Runups  Tsunami Magnitude (Abe)  \
# 2249                      0.80               5.0                      NaN
# 2271                      4.00               1.0                      NaN
# 2279                      3.00               3.0                      NaN
# 2283                      9.00               2.0                      NaN
# 2306                      2.00               1.0                      NaN
# 2307                     30.00               1.0                      NaN
# 2330                      3.00               1.0                      NaN
# 2331                      6.00               1.0                      NaN
# 2337                      2.00               3.0                      NaN
# 2339                      8.00               9.0                      NaN
# 2365                     10.90              41.0                      NaN
# 2370                      4.00               5.0                      NaN
# 2396                      0.08              14.0                      NaN
# 2400                      1.00               4.0                      NaN
# 2401                      6.00               1.0                      NaN
# 2427                     38.00               1.0                      NaN
# 2435                      0.19               2.0                      NaN
# 2500                       NaN               0.0                      NaN
# 2513                      1.80              38.0                      NaN
# 2517                      0.57              11.0                      NaN
# 2531                      2.50               5.0                      NaN
# 2532                      2.00               0.0                      NaN
# 2544                       NaN               0.0                      NaN
# 2551                    193.00               3.0                      NaN
# 2573                      3.00              27.0                      NaN
# 2594                      1.00               1.0                      NaN
# 2597                      0.22              10.0                      NaN
# 2610                     85.00             410.0                      NaN
# 2612                      1.75               2.0                      NaN
# 2622                      0.50               1.0                      NaN
# 2625                      0.50               1.0                      NaN
# 2649                      0.15               1.0                      NaN
# 2650                      0.10               1.0                      NaN
# 2651                     15.00             386.0                      NaN
# 2652                      0.36               1.0                      NaN
#
#       Tsunami Magnitude (Iida)  Tsunami Intensity
# 2249                      -0.3                NaN
# 2271                       NaN                4.0
# 2279                       1.2                NaN
# 2283                       3.5                2.5
# 2306                       NaN                2.0
# 2307                       NaN                NaN
# 2330                       NaN                NaN
# 2331                       NaN                4.0
# 2337                       NaN                NaN
# 2339                       NaN                NaN
# 2365                       NaN                5.0
# 2370                       NaN                NaN
# 2396                       NaN                NaN
# 2400                       NaN                NaN
# 2401                       NaN                NaN
# 2427                       NaN                NaN
# 2435                       NaN                NaN
# 2500                       NaN                NaN
# 2513                       NaN                NaN
# 2517                       NaN                NaN
# 2531                       NaN                NaN
# 2532                       NaN                NaN
# 2544                       NaN                NaN
# 2551                       NaN                NaN
# 2573                       NaN                NaN
# 2594                       NaN                NaN
# 2597                       NaN                NaN
# 2610                       NaN                NaN
# 2612                       NaN                NaN
# 2622                       NaN                NaN
# 2625                       NaN                NaN
# 2649                       NaN                NaN
# 2650                       NaN                NaN
# 2651                       NaN                NaN
# 2652                       NaN                NaN

# %%
df2.shape
# Out:
# (35, 18)

# %%
df[['Year', 'Mo', 'Dy', 'Hr', 'Mn', 'Sec']] = df[['Year', 'Mo', 'Dy', 'Hr', 'Mn', 'Sec']].fillna(0).astype(int)
df
# Out:
#       Year  Mo  Dy  Hr  Mn  Sec  Tsunami Event Validity  Tsunami Cause Code  \
# 2232  1990   2   8   7  15   32                     4.0                 1.0
# 2233  1990   2  20   6  53   39                     4.0                 1.0
# 2234  1990   3  25  13  22   55                     4.0                 1.0
# 2235  1990   4   5  21  12   35                     4.0                 1.0
# 2238  1990   9  23  21  13    7                     4.0                 1.0
# ...    ...  ..  ..  ..  ..  ...                     ...                 ...
# 2652  2022   1  16   0   0    0                     4.0                 6.0
# 2653  2022   1  29   2  46   39                     4.0                 1.0
# 2654  2022   3  16  14  36   33                     4.0                 1.0
# 2655  2022   3  30  20  56   58                     4.0                 1.0
# 2656  2022   3  31   5  44    1                     4.0                 1.0
#
#       Earthquake Magnitude        Country  \
# 2232                   6.6    PHILIPPINES
# 2233                   6.4          JAPAN
# 2234                   7.0     COSTA RICA
# 2235                   7.5  USA TERRITORY
# 2238                   6.5          JAPAN
# ...                    ...            ...
# 2652                   NaN          TONGA
# 2653                   6.5    NEW ZEALAND
# 2654                   7.3          JAPAN
# 2655                   6.9  NEW CALEDONIA
# 2656                   7.0  NEW CALEDONIA
#
#                             Location Name  Latitude  Longitude  \
# 2232                          PHILIPPINES     9.755    124.694
# 2233                                JAPAN    34.706    139.252
# 2234                           COSTA RICA     9.919    -84.808
# 2235   MARIANA TRENCH, N. MARIANA ISLANDS    15.125    147.596
# 2238  W. OF BONIN ISLANDS, IZU IS., JAPAN    33.267    138.643
# ...                                   ...       ...        ...
# 2652                        TONGA ISLANDS   -20.536   -175.382
# 2653                     KERMADEC ISLANDS   -29.531   -176.749
# 2654             OFF FUKUSHIMA PREFECTURE    37.702    141.587
# 2655                      LOYALTY ISLANDS   -22.716    170.286
# 2656                      LOYALTY ISLANDS   -22.579    170.354
#
#       Maximum Water Height (m)  Number of Runups  Tsunami Magnitude (Abe)  \
# 2232                      2.10               0.0                      NaN
# 2233                      0.16               1.0                      NaN
# 2234                      1.00               4.0                      NaN
# 2235                      1.80              34.0                      NaN
# 2238                      0.20               4.0                      NaN
# ...                        ...               ...                      ...
# 2652                      0.36               1.0                      NaN
# 2653                      0.10               1.0                      NaN
# 2654                      0.30               5.0                      NaN
# 2655                      0.07               3.0                      NaN
# 2656                      0.05               1.0                      NaN
#
#       Tsunami Magnitude (Iida)  Tsunami Intensity
# 2232                       NaN                NaN
# 2233                      -1.7                NaN
# 2234                       NaN                NaN
# 2235                      -1.0                NaN
# 2238                       NaN                NaN
# ...                        ...                ...
# 2652                       NaN                NaN
# 2653                       NaN                NaN
# 2654                       NaN                NaN
# 2655                       NaN                NaN
# 2656                       NaN                NaN
#
# [339 rows x 18 columns]

# %%
df.rename(columns = {'Year': 'year', 'Mo': "month", 'Dy': 'day', 'Hr': 'hour', 'Mn': 'minute', 'Sec': 'second'}, inplace=True)

# %%
df['datetime'] = pd.to_datetime(df[['year', 'month', 'day', 'hour', 'minute', 'second']])
